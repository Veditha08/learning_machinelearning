# %% [markdown]
# <a href="https://colab.research.google.com/github/Veditha08/learning_machinelearning/blob/main/numpy_basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
a = np.array([1,2,3])
print(a)
# Out:
# [1 2 3]

# %%
#get dimension
a.ndim
# Out:
# 1

# %%
b = np.array([[1,2,3],[2,3,5]])
#get shape
b.shape
# Out:
# (2, 3)

# %%
#get specific element [r, c]
b[1, 2]
# Out:
# np.int64(5)

# %%
#get specific row [1, :]; get specific column [:, 2]
b[0, :]
b[:, 1]
# Out:
# array([2, 3])

# %%
lap_times = np.array([1,2,3,4])
#in minutes:
lap_in_secs = lap_times * 60
print(lap_in_secs)
# Out:
# [ 60 120 180 240]
